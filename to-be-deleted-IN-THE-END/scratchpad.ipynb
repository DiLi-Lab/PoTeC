# %%
"""
to be deleted when everything is done, I'm just using it to the check the data types and the nan values in all csv files
+ print the markdown table + some other checks
"""
import json
from pathlib import Path

import pandas as pd
from tqdm import tqdm
import matplotlib.pyplot as plt

PATHS = [
    # 'stimuli/aoi_texts/aoi/b0.ias',
    'stimuli/word_features/word_features_b0.csv',
    'participants/participant_data.csv',
    'eyetracking_data/fixations/reader0_b0_fixations.csv',
    'eyetracking_data/reader_rm_wf/reader0_b0_merged.csv',
    'eyetracking_data/reading_measures/reader0_b0_rm.csv',
    'eyetracking_data/scanpaths/reader0_b0_scanpath.csv',
    'eyetracking_data/scanpaths_reader_rm_wf/reader0_b0_merged_sp_rm.csv',
]

PATHS_FOLDERS = [
    'stimuli/aoi_texts/aoi/',
    'stimuli/word_features/',
    'eyetracking_data/fixations/',
    'eyetracking_data/reader_rm_wf/',
    'eyetracking_data/reading_measures/',
    'eyetracking_data/scanpaths/',
    'eyetracking_data/scanpaths_reader_rm_wf/',
    'stimuli/stimuli/items.tsv',
    'stimuli/stimuli/stimuli.tsv',
    'participants/',      
]

floats = ['type_length_chars', 
          'lemma_length_chars', 
                     'type_length_syllables', 
    'annotated_type_frequency_normalized', 'type_frequency_normalized',
                     'lemma_frequency_normalized', 'familiarity_normalized', 'regularity_normalized',
                     'document_frequency_normalized', 'sentence_frequency_normalized',
                     'cumulative_syllable_corpus_frequency_normalized',
                     'cumulative_syllable_lexicon_frequency_normalized',
                     'cumulative_character_corpus_frequency_normalized',
                     'cumulative_character_lexicon_frequency_normalized',
                     'cumulative_character_bigram_corpus_frequency_normalized',
                     'cumulative_character_bigram_lexicon_frequency_normalized',
                     'cumulative_character_trigram_corpus_frequency_normalized',
                     'cumulative_character_trigram_lexicon_frequency_normalized',
                     'initial_letter_frequency_normalized',
                     'initial_bigram_frequency_normalized', 'initial_trigram_frequency_normalized',
                     'avg_cond_prob_in_bigrams',
                     'avg_cond_prob_in_trigrams', 'neighbors_coltheart_higher_freq_cum_freq_normalized',
                     'neighbors_coltheart_higher_freq_count_normalized',
                     'neighbors_coltheart_all_cum_freq_normalized',
                     'neighbors_coltheart_all_count_normalized',
                     'neighbors_levenshtein_higher_freq_cum_freq_normalized',
                     'neighbors_levenshtein_higher_freq_count_normalized',
                     'neighbors_levenshtein_all_cum_freq_normalized',
                     'neighbors_levenshtein_all_count_normalized']

# %%
other = []
for file in Path('/Users/debor/repos/PoTeC-data/eyetracking_data/raw_data').glob('*.csv'):
    
    reader_id, text_id, _ = file.stem.split('_')
    base = '/Users/debor/repos/PoTeC-data/eyetracking_data/raw_data_cleaned/'
    
    new_name = f'{base}reader{reader_id}_{text_id}_raw_data.tsv'
    
    tsv = pd.read_csv(file, sep=r'\s+', na_values=['.'])
    tsv.drop(columns=['dots', 'other'], inplace=True)
    
    tsv.to_csv(new_name, sep='\t', index=False)
# Out:
# 12002
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_b4_trial8.csv
# 41304
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_b1_trial3.csv
# 10252
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/99_b3_trial6.csv
# 10226
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_b2_trial3.csv
# 16660
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_p3_trial12.csv
# 12322
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/19_b2_trial11.csv
# 10554
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_b0_trial10.csv
# 14530
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_b0_trial11.csv
# 11862
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/91_b1_trial9.csv
# 13448
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_b5_trial7.csv
# 29198
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_p3_trial3.csv
# 12726
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/22_b0_trial1.csv
# 15648
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_p1_trial11.csv
# 11288
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/70_b1_trial3.csv
# 11186
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_p0_trial4.csv
# 12692
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/19_b3_trial5.csv
# 232612
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/83_b1_trial5.csv
# 15650
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_b2_trial5.csv
# 10582
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_p5_trial1.csv
# 13630
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_b1_trial5.csv
# 14592
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/72_b2_trial2.csv
# 12180
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_p4_trial3.csv
# 10156
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/102_b2_trial10.csv
# 22970
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/22_b3_trial9.csv
# 14724
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_b2_trial9.csv
# 12768
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_b4_trial8.csv
# 11490
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_p1_trial2.csv
# 10086
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_b4_trial2.csv
# 10256
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/102_p5_trial4.csv
# 215688
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/83_b3_trial6.csv
# 10086
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_b4_trial9.csv
# 10224
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_b5_trial8.csv
# 11296
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/22_p3_trial7.csv
# 15964
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_b2_trial12.csv
# 13564
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/81_p2_trial9.csv
# 10522
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_p2_trial6.csv
# 18944
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/32_b2_trial6.csv
# 12898
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_b2_trial4.csv
# 10688
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_b2_trial3.csv
# 14934
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_p4_trial7.csv
# 11708
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/8_b4_trial5.csv
# 12624
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/20_p5_trial5.csv
# 11148
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_b5_trial4.csv
# 16854
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_p1_trial1.csv
# 15856
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_p3_trial2.csv
# 10922
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_p1_trial1.csv
# 10616
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/81_p4_trial10.csv
# 14074
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_b4_trial8.csv
# 10526
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/83_b4_trial12.csv
# 16246
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/69_p5_trial2.csv
# 20534
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_b1_trial12.csv
# 15832
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_b3_trial7.csv
# 12626
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/70_b3_trial4.csv
# 13870
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/22_p5_trial11.csv
# 14492
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/19_p2_trial12.csv
# 27418
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_b1_trial8.csv
# 16904
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/8_p5_trial8.csv
# 12314
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/99_p3_trial5.csv
# 22464
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_p0_trial7.csv
# 11036
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/65_p1_trial8.csv
# 14922
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_p2_trial4.csv
# 14882
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/39_b4_trial10.csv
# 16916
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/81_p3_trial12.csv
# 13836
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_b1_trial1.csv
# 10208
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/99_p0_trial8.csv
# 11408
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_b0_trial10.csv
# 21434
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_b5_trial9.csv
# 11088
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_p5_trial6.csv
# 10516
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/19_b4_trial9.csv
# 10214
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/18_b3_trial12.csv
# 10642
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/15_p1_trial9.csv
# 18142
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/22_b1_trial6.csv
# 11180
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_p2_trial2.csv
# 14962
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_b3_trial7.csv
# 10208
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/15_b3_trial6.csv
# 13722
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_b3_trial12.csv
# 16180
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/18_b1_trial6.csv
# 12008
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/72_b3_trial12.csv
# 10546
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/32_p5_trial5.csv
# 25464
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/72_p0_trial11.csv
# 10974
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/70_p2_trial9.csv
# 22320
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_p5_trial6.csv
# 12780
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/90_p1_trial1.csv
# 24496
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_b3_trial11.csv
# 11088
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_p0_trial4.csv
# 13246
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/102_b5_trial12.csv
# 12576
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/70_p3_trial2.csv
# 10118
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_p2_trial1.csv
# 11078
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/19_p1_trial4.csv
# 11008
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_b0_trial10.csv
# 16680
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_b3_trial5.csv
# 12898
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_b0_trial10.csv
# 18346
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_p5_trial5.csv
# 14390
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_b5_trial9.csv
# 15328
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/65_p0_trial12.csv
# 12272
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/70_p0_trial12.csv
# 11458
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/81_b2_trial8.csv
# 17096
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/68_p2_trial5.csv
# 10470
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/99_p1_trial7.csv
# 11814
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/18_p2_trial7.csv
# 13916
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_b1_trial6.csv
# 19540
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_b3_trial11.csv
# 14290
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/81_p0_trial11.csv
# 10126
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/72_b1_trial4.csv
# 23250
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/90_p5_trial9.csv
# 15280
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/31_p4_trial11.csv
# 23484
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_p5_trial6.csv
# 34942
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_p0_trial9.csv
# 19932
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/93_p3_trial7.csv
# 24064
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/65_b4_trial1.csv
# 12362
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/92_p3_trial9.csv
# 14930
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/85_p5_trial3.csv
# 23266
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/82_p0_trial2.csv
# 11558
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/15_p0_trial1.csv
# 15060
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/70_p5_trial11.csv
# 14230
# /Users/debor/repos/PoTeC-data/eyetracking_data/raw_data/105_p5_trial9.csv

# %%
## investigate col values and distribution

values = {}
for folder in PATHS_FOLDERS:
    values[folder] = {}

    first = True
    suffix = '.ias' if folder == 'stimuli/aoi_texts/aoi/' else '.tsv'
    for path in tqdm(Path(folder).glob(f'*{suffix}'), desc=f'Checking files in {folder}'):

        csv = pd.read_csv(path, sep='\t', keep_default_na=False,
                          na_values=['#N/A', '#N/A N/A', '#NA', '-1.#IND', '-1.#QNAN', '-NaN', '-nan', '1.#IND',
                                     '1.#QNAN', '<NA>', 'N/A', 'NA', 'NaN', 'None', 'n/a', 'nan', ''])
        if first:
            all_files = csv
            first = False
        else:
            all_files = pd.concat([all_files, csv], ignore_index=True)

    print(len(all_files))
    cols = all_files.columns.tolist()
    for col in all_files.columns:
        try:
            values[folder][col] += all_files[col].tolist()
        except KeyError:
            values[folder][col] = all_files[col].tolist()

        if all_files[col].dtype in ['float64'] or col in floats:
            print(col)
            cols.remove(col)
            try:
                print(f'min: {all_files[col].min()} max: {all_files[col].max()} mean: {all_files[col].mean()} std: {all_files[col].std()}')
                all_files[col].astype('float64').plot.kde()
                plt.show()

            except ValueError:
                # print value if value if not numeric
                print([v for v in all_files[col].values if not isinstance(v, float)])
        
        elif all_files[col].dtype in ['int64']:
            print(col)
            cols.remove(col)            
            counts = all_files[col].value_counts()
            print(counts.to_dict())
            all_files[col].plot.hist()
            plt.show()

    print(cols)
    print(all_files.dtypes)
    print(all_files['type_length_chars'].value_counts())

# %%
## check duplicate columns
    
all_paths = [
    'stimuli/word_features',
]
cols1 = [
    'PoS_tag'

]
cols2 = [
    'STTS_PoS_tag'
]
    
for path, col1, col2 in zip(all_paths, cols1, cols2):

    files = Path(path).glob('*.csv')

    with open(f'stuff_to_check/mismatch_{Path(path).stem}_{col1}_{col2}.txt', 'w', encoding='utf8') as f:

        for path in files:

            csv = pd.read_csv(path, sep='\t', na_filter=False)

            c1, c2, word = csv[col1], csv[col2], csv['word']

            for idx, (v1, v2, w) in enumerate(zip(c1, c2, word)):
                if v1.lower() != v2.lower():
                    f.write(f'{path}\n')
                    f.write(f'Line: {idx + 1}\n')
                    f.write(f'{col1}: {v1}\t{col2}: {v2}\tword:{w}\n\n')
